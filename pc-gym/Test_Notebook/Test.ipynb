# %% [markdown]
# # pc-gym Test Notebook
#
# Tests constraints, disturbance, oracle on all three models

# %% [markdown]
# ## Libraries

# %%
# Import pc-gym
# git clone https://github.com/MaximilianB2/pc-gym.git
# cd pc-gym

# %%
from dataclasses import dataclass
import numpy as np 
import torch
import matplotlib.pyplot as plt 
import gymnasium as gym
import torch.nn.functional as F
import copy
from stable_baselines3 import PPO,SAC
from Models import Models_env
import jax.numpy as jnp
#Global params
T = 26
nsteps = 100

# %% [markdown]
# ## Rollout Function

# %% [markdown]
# ### 1.1 CSTR

# %%
#Enter required setpoints for each state. Enter None for states without setpoints.
SP = {
    'Ca': [0.85 for i in range(int(nsteps/2))] + [0.9 for i in range(int(nsteps/2))],
}

#Continuous box action space
action_space = {
    'low': np.array([295]),
    'high':np.array([302]) 
}
#Continuous box observation space
observation_space = {
    'low' : np.array([0.7,300,0.8]),
    'high' : np.array([1,350,0.9])  
}

r_scale ={
    'Ca': 5 #Reward scale for each state
}
env_params = {
    'Nx': 2, # Number of states
    'N': nsteps, # Number of time steps
    'tsim':T, # Simulation Time
    'Nu':1, # Number of control/actions
    'SP':SP, #Setpoint
    'o_space' : observation_space, #Observation space
    'a_space' : action_space, # Action space
    'x0': np.array([0.8,330,0.8]), # Initial conditions (torch.tensor)
    'model': 'cstr_ode', #Select the model
    'r_scale': r_scale, #Scale the L1 norm used for reward (|x-x_sp|*r_scale)
    'normalise_a': True, #Normalise the actions
    'normalise_o':True, #Normalise the states,
    'noise':True, #Add noise to the states
    'integration_method': 'casadi', #Select the integration method
    'noise_percentage':0.001 #Noise percentage
}
env = Models_env(env_params)

# %%
initial_policy = SAC.load('SAC_cstr.zip')

# %%
env.plot_rollout(initial_policy,10,oracle = True,dist_reward=True)
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************

# %% [markdown]
# ### 1.1.1 Reactor with JAX

# %%
#Enter required setpoints for each state. Enter None for states without setpoints.
SP = {
    'Ca': [0.8 for i in range(int(nsteps/2))] + [0.9 for i in range(int(nsteps/2))],
}

#Continuous box action space
action_space = {
    'low': np.array([295]),
    'high':np.array([302]) 
}
#Continuous box observation space
observation_space = {
    'low' : np.array([0.7,300,0.8]),
    'high' : np.array([1,350,0.9])  
}

r_scale ={
    'Ca': 5
}
env_params = {
    'Nx': 2, # Number of states
    'N': nsteps, # Number of time steps
    'tsim':T, # Simulation Time
    'Nu':1, # Number of control/actions
    'SP':SP, #Setpoint
    'o_space' : observation_space, #Observation space
    'a_space' : action_space, # Action space
    'dt': 1., # Time step
    'x0': np.array([0.8,330,0.8]), # Initial conditions (torch.tensor)
    'model': 'cstr_ode', #Select the model
    'r_scale': r_scale, #Scale the L1 norm used for reward (|x-x_sp|*r_scale)
    'normalise_a': True, #Normalise the actions
    'normalise_o':True, #Normalise the states,
    'noise':True, #Add noise to the states
    'integration_method': 'jax',
    'noise_percentage':0.001
}
env = Models_env(env_params)

# %%
env.plot_rollout(initial_policy,10,oracle = True,dist_reward=True)

# %% [markdown]
# ### 1.2 First Order System

# %%
SP = {
    'x': [5 for i in range(int(nsteps/2))] + [8 for i in range(int(nsteps/2))]
}

action_space = {
    'low': np.array([0]),
    'high':np.array([10]) 
}

observation_space = {
    'low' : np.array([0,4]),
    'high' : np.array([10,6])  
}

r_scale = {
    'x': 1,
}
env_params_fos = {
    'Nx': 1,
    'N': nsteps,
    'tsim':T,
    'Nu':1,
    'SP':SP,
    'o_space' : observation_space,
    'a_space' : action_space,
    'dt': 1,
    'x0': np.array([0.,5.]),
    'model': 'first_order_system_ode', 
    'r_scale': r_scale,
    'normalise_a': True, #Normalise the actions
    'normalise_o':True, #Normalise the states,
    'noise':False, #Add noise to the states
    'noise_percentage':0.01,
    'integration_method': 'casadi'
}
first_order_env = Models_env(env_params_fos)

# %%
fos_policy = SAC.load('SAC_fos.zip')

# %%
first_order_env.plot_rollout(fos_policy,10,oracle=True,dist_reward=True,MPC_params={'N':10,'R':0.0})

# %% [markdown]
# ### 1.3 Multi-Stage Extraction Column

# %%
SP = {
      'X5': [0.3 for i in range(int(nsteps/4))] + [0.4 for i in range(int(nsteps/2))]+ [0.3 for i in range(int(nsteps/4))],
  }

action_space = {
    'low': np.array([5,10]),
    'high':np.array([500,1000])
}

observation_space = {
    'low' : np.array([0]*10+[0.3]),
    'high' : np.array([1]*10+[0.4])  
}


r_scale = {
    'X5': 1
}
env_params_ms = {
    'Nx': 10,
    'N': nsteps,
    'tsim':T,
    'Nu':2,
    'SP':SP,
    'o_space' : observation_space,
    'a_space' : action_space,
    'dt': 1,
    'x0': np.array([0.55, 0.3, 0.45, 0.25, 0.4, 0.20, 0.35, 0.15, 0.25, 0.1,0.3]),
    'model': 'multistage_extraction_ode', 
    'r_scale': r_scale,
    'normalise_a': True, #Normalise the actions
    'normalise_o':True, #Normalise the states,
    'noise':False, #Add noise to the states
    'noise_percentage':0,
    'integration_method': 'casadi'
}
multistage_env = Models_env(env_params_ms)

# %%
ms_policy = SAC.load("SAC_multistage")

# %%
multistage_env.plot_rollout(ms_policy,1,oracle=True,dist_reward=True)
# Out:
# CasADi - 2024-03-07 10:38:44 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:44 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 42, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:45 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 20, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:47 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:47 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 42, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:47 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:47 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:47 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 34, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:47 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 32, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:47 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 22, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:52 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:52 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:52 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:52 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:52 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:52 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 42, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:52 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:52 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 44, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:52 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:52 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 34, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 34, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 36, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 34, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 34, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 42, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 42, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 30, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 32, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:53 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:54 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:54 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:54 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:54 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:54 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:54 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:54 WARNING("solver:nlp_g failed: Inf detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:54 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:54 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:55 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]
# CasADi - 2024-03-07 10:38:55 WARNING("solver:nlp_g failed: NaN detected for output g, at (row 40, col 0).") [.../casadi/core/oracle_function.cpp:377]

# %% [markdown]
# ## 2. Disturbance Function

# %% [markdown]
# ### 2.1 Reactor Disturbance

# %%
disturbance = {'Caf': np.repeat([1, 1.05, 1], [nsteps//4, nsteps//2, nsteps//4])}
env = Models_env({**env_params, 'disturbances': disturbance}).plot_rollout(initial_policy, reps = 10, oracle= True)

# %% [markdown]
# ### 2.2 Multistage Extraction

# %%
disturbance = {
    'Y6': np.array([0.05 for i in range(int(nsteps/4))]+[1 for i in range(int(nsteps/2))]+[0.05 for i in range(int(nsteps/4))]),
}

env_params_ms.update({'disturbances': disturbance,})
                

multistage_env = Models_env(env_params_ms)

multistage_env.plot_rollout(ms_policy,10)

# %% [markdown]
# ## 3. Constraint Function

# %% [markdown]
# ### 3.1 Reactor Constraint

# %%
cons = {
    'T': 319
}

cons_type = {
    'T':'>='
}

env_params.update({
'done_on_cons_vio':False,
'constraints': cons, 
'cons_type': cons_type,
'r_penalty': True})
env_params.pop('disturbances', None)
env = Models_env(env_params)
env.plot_rollout(initial_policy,10,cons_viol=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 15
#       9 env_params.update({
#      10 'done_on_cons_vio':False,
#      11 'constraints': cons,
#      12 'cons_type': cons_type,
#      13 'r_penalty': True})
#      14 env_params.pop('disturbances', None)
# ---> 15 env = Models_env(env_params)
#      16 env.plot_rollout(initial_policy,10,cons_viol=True)
#
# File c:\Users\mfb22\Documents\GitHub\pc-gym\pc-gym\Models.py:63, in Models_env.__init__(self, env_params)
#      61     self.n_con = 0
#      62     for _, con_list in self.constraints.items():
# ---> 63         self.n_con += len(con_list)
#      64     self.info['cons_info'] = np.zeros((self.n_con,self.N,1))
#      66 if env_params.get('custom_con') is not None:
#
# TypeError: object of type 'int' has no len()

# %% [markdown]
# ### 3.2 First-Order-System Constraint

# %%
cons = {
    'x': [5,7.5]
}

cons_type = {
    'x': ['<=','>=']
}

env_params_fos.update({
'done_on_cons_vio':False,
'constraints': cons, 
'cons_type': cons_type,
'r_penalty': True})
env_params_fos.get('constraints') is not None
env = Models_env(env_params_fos)
env.plot_rollout(fos_policy,10,cons_viol=True)

# %% [markdown]
# ### 3.3 Multistage Extraction Constraint

# %%
cons = {
    'X1': 0.6,
}

cons_type = {
    'X1':'<='
}

env_params_ms.update({
'done_on_cons_vio':False,
'constraints': cons, 
'cons_type': cons_type,
'r_penalty': True})
env_params_ms.get('constraints') is not None
env = Models_env(env_params_ms)
env.plot_rollout(ms_policy,10)
