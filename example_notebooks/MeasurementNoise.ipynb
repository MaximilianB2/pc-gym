# %% [markdown]
# # Measurement Noise
#
# This notebook describes how to add measurement noise to individual states within pc-gym.

# %%
from pcgym import make_env
import numpy as np 
from stable_baselines3 import PPO

# %%
T = 26
nsteps = 100
SP = {
    'Ca': [0.85 for i in range(int(nsteps/2))] + [0.9 for i in range(int(nsteps/2))],
}

# %% [markdown]
# To add measurement noise to a state, we create a dictionary of states and their corresponding noise percentages. This dictionary is then passed to the environment in the `env_params` dictionary.

# %%
action_space = {
    'low': np.array([295]),
    'high':np.array([302]) 
}

r_scale ={
    'Ca': 1e3 #Reward scale for each state
}

# Continuous box observation space
observation_space = {
    'low' : np.array([0.7,300,0.8]),
    'high' : np.array([1,350,0.9])  
}


env_params = {
    'N': nsteps, # Number of time steps
    'tsim':T, # Simulation Time
    'SP':SP, # Setpoint
    'o_space' : observation_space, # Observation space
    'a_space' : action_space, # Action space
    'x0': np.array([0.8,330,0.8]), # Initial conditions 
    'model': 'cstr', # Select the model
    'normalise_a': True, # Normalise the actions
    'normalise_o':True, # Normalise the states,
    'noise':True, # Add noise to the states
    'integration_method': 'casadi', # Select the integration method
    'r_scale': r_scale, # Reward scaling
    'noise_percentage':{'Ca':0.01,'T':0.0005}, # Noise percentage

    
}
env = make_env(env_params)

# %%
nsteps_learning = 1e4
PPO_policy = PPO('MlpPolicy', env, verbose=1,learning_rate=0.001).learn(nsteps_learning)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\mfb22\AppData\Local\anaconda3\envs\pcgym_test\Lib\site-packages\gymnasium\spaces\box.py:235: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# c:\Users\mfb22\AppData\Local\anaconda3\envs\pcgym_test\Lib\site-packages\gymnasium\spaces\box.py:305: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -105     |
# | time/              |          |
# |    fps             | 599      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99          |
# |    ep_rew_mean          | -89.2       |
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006662555 |
# |    clip_fraction        | 0.0459      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | -0.00339    |
# |    learning_rate        | 0.001       |
# |    loss                 | 19.3        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00318    |
# |    std                  | 1.02        |
# |    value_loss           | 121         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99          |
# |    ep_rew_mean          | -67.2       |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 3           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.003637241 |
# |    clip_fraction        | 0.0508      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 0.001       |
# |    loss                 | 46.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00632    |
# |    std                  | 1.05        |
# |    value_loss           | 103         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 99           |
# |    ep_rew_mean          | -58.5        |
# | time/                   |              |
# |    fps                  | 359          |
# |    iterations           | 4            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0045484686 |
# |    clip_fraction        | 0.0554       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.739        |
# |    learning_rate        | 0.001        |
# |    loss                 | 45.1         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00391     |
# |    std                  | 1.05         |
# |    value_loss           | 94.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 99           |
# |    ep_rew_mean          | -61.2        |
# | time/                   |              |
# |    fps                  | 361          |
# |    iterations           | 5            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0076145157 |
# |    clip_fraction        | 0.0651       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.757        |
# |    learning_rate        | 0.001        |
# |    loss                 | 45           |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00477     |
# |    std                  | 1.04         |
# |    value_loss           | 81.1         |
# ------------------------------------------

# %%
evaluator, data = env.plot_rollout({'PPO': PPO_policy}, oracle = True, reps = 10)
