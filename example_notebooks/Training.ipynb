# %% [markdown]
# # Example Training Notebook
#
# This notebook describes how to train an RL policy with the PPO algorithm using the Stable Baselines 3 package

# %%
from pcgym import make_env
import numpy as np 
from stable_baselines3 import PPO

# %% [markdown]
# First define the total time of simulation and the number of steps

# %%
# Enter required setpoints for each state.
T = 26
nsteps = 100
SP = {
    'Ca': [0.85 for i in range(int(nsteps/2))] + [0.9 for i in range(int(nsteps/2))],
}

# %% [markdown]
# Define and make the environment

# %%
# Continuous box action space
action_space = {
    'low': np.array([295]),
    'high':np.array([302]) 
}

# Continuous box observation space
observation_space = {
    'low' : np.array([0.7,300,0.8]),
    'high' : np.array([1,350,0.9])  
}

r_scale ={
    'Ca': 1e3 #Reward scale for each state
}
env_params = {
    'N': nsteps, # Number of time steps
    'tsim':T, # Simulation Time
    'SP':SP, # Setpoint
    'o_space' : observation_space, # Observation space
    'a_space' : action_space, # Action space
    'x0': np.array([0.8,330,0.8]), # Initial conditions 
    'model': 'cstr', # Select the model
    'r_scale': r_scale, # Scale the L1 norm used for reward (|x-x_sp|*r_scale)
    'normalise_a': True, # Normalise the actions
    'normalise_o':True, # Normalise the states,
    'noise':True, # Add noise to the states
    'integration_method': 'casadi', # Select the integration method
    'noise_percentage':0.001 # Noise percentage
}
env = make_env(env_params)

# %% [markdown]
# The model specification can now be displayed by calling the following method.

# %%
env.model.info()
# Out:
# {'parameters': {'q': 100,
#   'V': 100,
#   'rho': 1000,
#   'C': 0.239,
#   'deltaHr': -50000.0,
#   'EA_over_R': 8750,
#   'k0': 72000000000.0,
#   'UA': 50000.0,
#   'Ti': 350,
#   'Caf': 1,
#   'states': ['Ca', 'T'],
#   'inputs': ['Tc'],
#   'disturbances': ['Ti', 'Caf'],
#   'uncertainties': None},
#  'states': ['Ca', 'T'],
#  'inputs': ['Tc'],
#  'disturbances': ['Ti', 'Caf'],
#  'uncertainties': []}

# %% [markdown]
# Create and train the agent with PPO

# %%
nsteps_learning = 1e4
PPO_policy = PPO('MlpPolicy', env, verbose=1,learning_rate=0.001).learn(nsteps_learning)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -122     |
# | time/              |          |
# |    fps             | 740      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 99         |
# |    ep_rew_mean          | -89.7      |
# | time/                   |            |
# |    fps                  | 579        |
# |    iterations           | 2          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00973966 |
# |    clip_fraction        | 0.0798     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.43      |
# |    explained_variance   | -0.016     |
# |    learning_rate        | 0.001      |
# |    loss                 | 33.9       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.00933   |
# |    std                  | 1.02       |
# |    value_loss           | 147        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99          |
# |    ep_rew_mean          | -86.5       |
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006785542 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.001       |
# |    loss                 | 24          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00559    |
# |    std                  | 1.05        |
# |    value_loss           | 93          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99          |
# |    ep_rew_mean          | -39.7       |
# | time/                   |             |
# |    fps                  | 618         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.005581173 |
# |    clip_fraction        | 0.0638      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.768       |
# |    learning_rate        | 0.001       |
# |    loss                 | 42.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0035     |
# |    std                  | 1.04        |
# |    value_loss           | 87.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 99         |
# |    ep_rew_mean          | -55.4      |
# | time/                   |            |
# |    fps                  | 641        |
# |    iterations           | 5          |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.00912559 |
# |    clip_fraction        | 0.108      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.45      |
# |    explained_variance   | 0.75       |
# |    learning_rate        | 0.001      |
# |    loss                 | 42.1       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.00631   |
# |    std                  | 1.02       |
# |    value_loss           | 97.9       |
# ----------------------------------------

# %% [markdown]
# Use the `plot_rollout` method to plot 10 repetitions of the PPO policy. The method outputs an instance of the evaluator class and the data used for the plots

# %%
evaluator, data = env.plot_rollout({'PPO': PPO_policy}, reps = 10)
