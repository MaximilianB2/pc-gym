# %% [markdown]
# # Cloning the Repository (pc-gym)

# %%
# !dir pc-gym
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is F0B8-32A3
#
#  Directory of c:\Users\Usuario\Desktop\imperial_projects\VSCode\pcgym2\train\base
# File Not Found

# %%
# %cd pc-gym

# %% [markdown]
# # Importing Libraries

# %%
# %cd src

# %%
# %cd pcgym

# %%
# %cd C:/Users/Usuario/Desktop/imperial_projects/VSCode/pcgym2/pc-gym
# Out:
# C:\Users\Usuario\Desktop\imperial_projects\VSCode\pcgym2\pc-gym
# c:\Users\Usuario\Desktop\imperial_projects\VSCode\pcgym2\new_venv\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from dataclasses import dataclass
import numpy as np
import torch
import matplotlib.pyplot as plt
import gymnasium as gym
import torch.nn.functional as F
import copy
from stable_baselines3 import PPO,SAC,DDPG,TD3
import pcgym
from pcgym import make_env
import jax.numpy as jnp
#Global params
T = 26
nsteps = 60
# Global seed for reproducibility
seed = 1990
# Out:
# C:\Users\mfb22\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\do_mpc\sysid\__init__.py:15: UserWarning: The ONNX feature is not available. Please install the full version of do-mpc to access this feature.
#   warnings.warn('The ONNX feature is not available. Please install the full version of do-mpc to access this feature.')
# C:\Users\mfb22\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\do_mpc\opcua\__init__.py:14: UserWarning: The opcua feature is not available. Please install the full version of do-mpc to access this feature.
#   warnings.warn('The opcua feature is not available. Please install the full version of do-mpc to access this feature.')

# %% [markdown]
# # Saving and loading
#
# Saving and loading stable-baselines models is straightforward: you can directly call `.save()` and `.load()` on the models.

# %%
import os
# Create save dir
save_dir = "./max/ppo"
os.makedirs(save_dir, exist_ok=True)

# %% [markdown]
# # Monitoring experiments with W&B

# %%
# !wandb login 84af17cc9914cf1736f3a8e2733a2f361e4750bb
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\Usuario\.netrc

# %% [markdown]
# # 1.1 Reactor Case Study

# %%
# @title Function to log the performance data
def log_performance(performance, test_label, file_path):
    with open(file_path, "a") as file:
        file.write(f"{test_label}: \n")
        file.write(f"scalarised_performance: {performance}\n\n")

file_path = f"{save_dir}/lcb_metric_safe.txt"

# %% [markdown]
# ### RL training

# %%
import numpy as np
import torch as th
from torch import nn  # Import torch.nn for activation functions

# Learning rate decay schedule
def cosine_annealing_schedule(progress_remaining: float, num_cycles=1, min_lr=0.005, max_lr=0.01):
    progress = 1.0 - progress_remaining
    lr = min_lr + (max_lr - min_lr) / 2 * (1 + np.cos(np.pi * num_cycles * progress))
    return lr

# Configuration for reinforcement learning model
config = {
    "policy": 'MlpPolicy',  # default: MlpPolicy
    "seed": 1990,
    "check_freq": 1e3,  # base: 12000 (~100 episodes)
    "n_eval_episodes": 1,  # evaluate the agent over 100 episodes in the evaluation environment
    "positive_definiteness_penalty_weight": 0,  # Set to 0 initially
    "derivative_penalty_weight": 0,  # Set to 0 initially
    'use_direct_penalty': False,  # choose between applying a penalty directly to the critic loss or adjusting the Q target values (derivative penalty)
    'allowed_increase_factor': 1,  # max increase value for both methods (derivative penalty)
    'total_timesteps': 100000,
}

# The best hyperparameters found in previous runs
best_params = {
    'min_lr': 1.790271571814614e-05,
    'max_lr': 0.021830951495112202,
    'pi_layer_0_units': 5,
    'pi_layer_1_units': 3,
    'qf_layer_0_units': 6,
    'qf_layer_1_units': 2,
    'activation_fn': 'ReLU',
    'n_steps': 2048,
    'batch_size': 128,
    'n_epochs': 11,
    'ent_coef': 2.847818037607558e-06,
    'clip_range': 0.23324165337690744,
    'gamma': 0.9095905120763823,
    'gae_lambda': 0.8795346055547795,
    'vf_coef': 0.17896972094727606,
    'max_grad_norm': 0.49101636537830917,
    'total_timesteps': 200000
}

# Update the config dictionary with the best parameters
config.update(best_params)

# Set the activation function directly based on best_params
if best_params['activation_fn'] == 'Tanh':
    activation_fn = th.nn.Tanh
elif best_params['activation_fn'] == 'ReLU':
    activation_fn = th.nn.ReLU
elif best_params['activation_fn'] == 'LeakyReLU':
    activation_fn = th.nn.LeakyReLU
else:
    raise ValueError("Unsupported activation function")

# # Create policy_kwargs with the fixed network architecture and activation function from best_params
policy_kwargs = dict(
    activation_fn=activation_fn,  # Use the activation function directly
    net_arch=dict(
        pi=[2 ** best_params['pi_layer_0_units'], 2 ** best_params['pi_layer_1_units']],
        qf=[2 ** best_params['qf_layer_0_units'], 2 ** best_params['qf_layer_1_units']]
    )
)

# %%
import torch as th
import numpy as np
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.common.policies import ActorCriticPolicy
from stable_baselines3.common.vec_env import DummyVecEnv

##################################################################################
# Environment and RL Definition
##################################################################################

# Enter required setpoints for each state. Enter None for states without setpoints.
SP = {
    'T': [340.0 for _ in range(nsteps)],
}

# Continuous box action space
action_space = {
    'low': np.array([250]),
    'high': np.array([350])
}

# Continuous box observation space ([CA, T, CA_Setpoint, T_Setpoint])
observation_space = {
    'low': np.array([0.0, 300, 300]),
    'high': np.array([1, 450, 400])
}

# Define disturbance bounds
disturbance_bounds = {
    'low': np.array([340]),
    'high': np.array([360])
}

r_scale = {
    'T': 1e-6  # Reward scale for each state,
}
# Environment parameters
env_params_template = {
    'Nx': 2,
    'N': 60,
    'tsim': 26,
    'Nu': 1,
    'SP': SP,
    'o_space': observation_space,
    'a_space': action_space,
    'x0': np.array([0.87725294608097, 324.475443431599, 324.475443431599]),
    'model': 'cstr',
    'normalise_a': True,
    'normalise_o': True,
    'noise': True,
    'r_scale': r_scale,
    'integration_method': 'casadi',
    'noise_percentage': 0.001,  # 0.001,
    'disturbance_bounds': disturbance_bounds
}

# Add noise_percentage from env_params to config
config['noise_percentage'] = env_params_template['noise_percentage']

# Seed everything for reproducibility
def set_global_seeds(seed):
    np.random.seed(seed)
    th.manual_seed(seed)
    if th.cuda.is_available():
        th.cuda.manual_seed_all(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

# Function to create random disturbances
def create_random_disturbances(seed, nsteps, low=349, high=351):
    # Set the global seed for reproducibility
    set_global_seeds(seed)
    value = np.random.uniform(low, high, 1)[0]  # Generate a single random disturbance value within the specified range
    disturbances = {'Ti': [350] * (nsteps // 3) + [value] * (nsteps // 3) + [350] * (nsteps // 3)}  # Repeat each disturbance value for nsteps/3 times
    return disturbances
# Create multiple environments with different disturbances
def create_parallel_envs(n_envs, seed):
    set_global_seeds(seed)
    envs = []
    disturbances_list = []
    for i in range(n_envs):
        env_params = env_params_template.copy()
        disturbances = create_random_disturbances(seed + i, nsteps)
        env_params.update({'disturbances': disturbances})
        disturbances_list.append(disturbances)
        envs.append(lambda: make_env(env_params))
    return DummyVecEnv(envs), disturbances_list

# Create evaluation environment using DummyVecEnv
def create_eval_env(seed, n_envs=1):
    set_global_seeds(seed)
    envs = []
    for i in range(n_envs):
        env_params = env_params_template.copy()
        disturbances = create_random_disturbances(seed + i, nsteps)
        env_params.update({'disturbances': disturbances})
        envs.append(lambda: make_env(env_params))
    return DummyVecEnv(envs)

eval_env = create_eval_env(seed=config['seed'], n_envs=1)

# %%
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3 import PPO



# Set the global seed for reproducibility
set_global_seeds(config['seed'])

# Number of parallel environments
n_envs = 1

# Create the parallel environments and get the disturbances
env, disturbances_list = create_parallel_envs(n_envs, config['seed'])

# Print the first disturbances
print("First disturbance used in training:", disturbances_list[0])

# Training the model
model = PPO(
    config['policy'],
    env,
    learning_rate= 1e-3,#lambda progress: cosine_annealing_schedule(progress, min_lr=config['min_lr'], max_lr=config['max_lr']),  # Cosine schedule
    verbose = 1# Adding the optimized PPO-specific parameters to the model
)

# Create the evaluation environment
eval_env = create_eval_env(seed)

# Create evaluation callback

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=save_dir,
    log_path=save_dir,
    eval_freq=config['check_freq'],
    n_eval_episodes=config['n_eval_episodes'],
    deterministic=True,
    render=False
)
# Train the model with the callbacks
model.learn(total_timesteps=config['total_timesteps'],callback=eval_callback)

# Save the model
model.save(save_dir)

# Save the disturbances to a file for future reference
disturbances_file_path = os.path.join(save_dir, "disturbances_used_in_training.txt")
with open(disturbances_file_path, "w") as f:
    for i, disturbance in enumerate(disturbances_list):
        f.write(f"Disturbance {i+1}: {disturbance}\n")
# Out:
# First disturbance used in training: {'Ti': [350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350.44395451498445, 350.44395451498445, 350.44395451498445, 350.44395451498445, 350.44395451498445, 350.44395451498445, 350.44395451498445, 350.44395451498445, 350.44395451498445, 350.44395451498445, 350.44395451498445, 350.44395451498445, 350.44395451498445, 350.44395451498445, 350.44395451498445, 350.44395451498445, 350.44395451498445, 350.44395451498445, 350.44395451498445, 350.44395451498445, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350, 350]}
# Using cuda device
# Eval num_timesteps=1000, episode_reward=-0.01 +/- 0.00
# Episode length: 59.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 59       |
# |    mean_reward     | -0.0146  |
# | time/              |          |
# |    total_timesteps | 1000     |
# ---------------------------------
# New best mean reward!
# Eval num_timesteps=2000, episode_reward=-0.01 +/- 0.00
# Episode length: 59.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 59       |
# |    mean_reward     | -0.0148  |
# | time/              |          |
# |    total_timesteps | 2000     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 252  |
# |    iterations      | 1    |
# |    time_elapsed    | 8    |
# |    total_timesteps | 2048 |
# -----------------------------
# Eval num_timesteps=3000, episode_reward=-0.01 +/- 0.00
# Episode length: 59.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 59          |
# |    mean_reward          | -0.0126     |
# | time/                   |             |
# |    total_timesteps      | 3000        |
# | train/                  |             |
# |    approx_kl            | 0.008654049 |
# |    clip_fraction        | 0.0698      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | -15.1       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0128     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00523    |
# |    std                  | 1.03        |
# |    value_loss           | 0.000341    |
# -----------------------------------------
# New best mean reward!
# Eval num_timesteps=4000, episode_reward=-0.01 +/- 0.00
# Episode length: 59.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 59       |
# |    mean_reward     | -0.0127  |
# | time/              |          |
# |    total_timesteps | 4000     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 216  |
# |    iterations      | 2    |
# |    time_elapsed    | 18   |
# |    total_timesteps | 4096 |
# -----------------------------
# Eval num_timesteps=5000, episode_reward=-0.03 +/- 0.00
# Episode length: 59.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 59          |
# |    mean_reward          | -0.0341     |
# | time/                   |             |
# |    total_timesteps      | 5000        |
# | train/                  |             |
# |    approx_kl            | 0.007707583 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.0342      |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0285     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 1.03        |
# |    value_loss           | 0.000325    |
# -----------------------------------------
# Eval num_timesteps=6000, episode_reward=-0.03 +/- 0.00
# Episode length: 59.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 59       |
# |    mean_reward     | -0.0342  |
# | time/              |          |
# |    total_timesteps | 6000     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 209  |
# |    iterations      | 3    |
# |    time_elapsed    | 29   |
# |    total_timesteps | 6144 |
# -----------------------------
# Eval num_timesteps=7000, episode_reward=-0.06 +/- 0.00
# Episode length: 59.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 59          |
# |    mean_reward          | -0.055      |
# | time/                   |             |
# |    total_timesteps      | 7000        |
# | train/                  |             |
# |    approx_kl            | 0.008042225 |
# |    clip_fraction        | 0.0826      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.0725      |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.00204    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00715    |
# |    std                  | 0.991       |
# |    value_loss           | 0.000456    |
# -----------------------------------------
# Eval num_timesteps=8000, episode_reward=-0.06 +/- 0.00
# Episode length: 59.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 59       |
# |    mean_reward     | -0.055   |
# | time/              |          |
# |    total_timesteps | 8000     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 206  |
# |    iterations      | 4    |
# |    time_elapsed    | 39   |
# |    total_timesteps | 8192 |
# -----------------------------
# Eval num_timesteps=9000, episode_reward=-0.08 +/- 0.00
# Episode length: 59.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 59         |
# |    mean_reward          | -0.0787    |
# | time/                   |            |
# |    total_timesteps      | 9000       |
# | train/                  |            |
# |    approx_kl            | 0.00692437 |
# |    clip_fraction        | 0.0699     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.39      |
# |    explained_variance   | 0.0562     |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.00658    |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.00472   |
# |    std                  | 0.966      |
# |    value_loss           | 0.000594   |
# ----------------------------------------
# Eval num_timesteps=10000, episode_reward=-0.08 +/- 0.00
# Episode length: 59.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 59       |
# |    mean_reward     | -0.0787  |
# | time/              |          |
# |    total_timesteps | 10000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 205   |
# |    iterations      | 5     |
# |    time_elapsed    | 49    |
# |    total_timesteps | 10240 |
# ------------------------------
# Eval num_timesteps=11000, episode_reward=-0.08 +/- 0.00
# Episode length: 59.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 59          |
# |    mean_reward          | -0.0801     |
# | time/                   |             |
# |    total_timesteps      | 11000       |
# | train/                  |             |
# |    approx_kl            | 0.004088478 |
# |    clip_fraction        | 0.0432      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.061       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0068     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00181    |
# |    std                  | 0.945       |
# |    value_loss           | 0.000602    |
# -----------------------------------------
# Eval num_timesteps=12000, episode_reward=-0.08 +/- 0.00
# Episode length: 59.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 59       |
# |    mean_reward     | -0.08    |
# | time/              |          |
# |    total_timesteps | 12000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 204   |
# |    iterations      | 6     |
# |    time_elapsed    | 60    |
# |    total_timesteps | 12288 |
# ------------------------------
# Eval num_timesteps=13000, episode_reward=-0.09 +/- 0.00
# Episode length: 59.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 59           |
# |    mean_reward          | -0.0881      |
# | time/                   |              |
# |    total_timesteps      | 13000        |
# | train/                  |              |
# |    approx_kl            | 0.0048982687 |
# |    clip_fraction        | 0.0623       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.0782      |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.00126      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0045      |
# |    std                  | 0.933        |
# |    value_loss           | 0.000597     |
# ------------------------------------------
# Eval num_timesteps=14000, episode_reward=-0.09 +/- 0.00
# Episode length: 59.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 59       |
# |    mean_reward     | -0.0881  |
# | time/              |          |
# |    total_timesteps | 14000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 203   |
# |    iterations      | 7     |
# |    time_elapsed    | 70    |
# |    total_timesteps | 14336 |
# ------------------------------
# Eval num_timesteps=15000, episode_reward=-0.09 +/- 0.00
# Episode length: 59.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 59          |
# |    mean_reward          | -0.0874     |
# | time/                   |             |
# |    total_timesteps      | 15000       |
# | train/                  |             |
# |    approx_kl            | 0.005849063 |
# |    clip_fraction        | 0.0509      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.0246      |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.00737     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00202    |
# |    std                  | 0.889       |
# |    value_loss           | 0.000597    |
# -----------------------------------------
# Eval num_timesteps=16000, episode_reward=-0.09 +/- 0.00
# Episode length: 59.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 59       |
# |    mean_reward     | -0.0874  |
# | time/              |          |
# |    total_timesteps | 16000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 202   |
# |    iterations      | 8     |
# |    time_elapsed    | 80    |
# |    total_timesteps | 16384 |
# ------------------------------
# Eval num_timesteps=17000, episode_reward=-0.08 +/- 0.00
# Episode length: 59.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 59           |
# |    mean_reward          | -0.0826      |
# | time/                   |              |
# |    total_timesteps      | 17000        |
# | train/                  |              |
# |    approx_kl            | 0.0046103057 |
# |    clip_fraction        | 0.0627       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.00444      |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.00482      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00351     |
# |    std                  | 0.864        |
# |    value_loss           | 0.000673     |
# ------------------------------------------
# Eval num_timesteps=18000, episode_reward=-0.08 +/- 0.00
# Episode length: 59.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 59       |
# |    mean_reward     | -0.0826  |
# | time/              |          |
# |    total_timesteps | 18000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 202   |
# |    iterations      | 9     |
# |    time_elapsed    | 91    |
# |    total_timesteps | 18432 |
# ------------------------------
# Eval num_timesteps=19000, episode_reward=-0.09 +/- 0.00
# Episode length: 59.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 59           |
# |    mean_reward          | -0.0876      |
# | time/                   |              |
# |    total_timesteps      | 19000        |
# | train/                  |              |
# |    approx_kl            | 0.0013852611 |
# |    clip_fraction        | 0.0272       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.00658      |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.00107      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 0.000406     |
# |    std                  | 0.855        |
# |    value_loss           | 0.000621     |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=-0.09 +/- 0.00
# Episode length: 59.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 59       |
# |    mean_reward     | -0.0876  |
# | time/              |          |
# |    total_timesteps | 20000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 201   |
# |    iterations      | 10    |
# |    time_elapsed    | 101   |
# |    total_timesteps | 20480 |
# ------------------------------
# Eval num_timesteps=21000, episode_reward=-0.10 +/- 0.00
# Episode length: 59.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 59          |
# |    mean_reward          | -0.0968     |
# | time/                   |             |
# |    total_timesteps      | 21000       |
# | train/                  |             |
# |    approx_kl            | 0.004922085 |
# |    clip_fraction        | 0.0523      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.0744      |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.015      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00231    |
# |    std                  | 0.834       |
# |    value_loss           | 0.000605    |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 43
#      33 eval_callback = EvalCallback(
#      34     eval_env,
#      35     best_model_save_path=save_dir,
#    (...)
#      40     render=False
#      41 )
#      42 # Train the model with the callbacks
# ---> 43 model.learn(total_timesteps=config['total_timesteps'],callback=eval_callback)
#      45 # Save the model
#      46 model.save(save_dir)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\ppo\ppo.py:315, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306 def learn(
#     307     self: SelfPPO,
#     308     total_timesteps: int,
#    (...)
#     313     progress_bar: bool = False,
#     314 ) -> SelfPPO:
# --> 315     return super().learn(
#     316         total_timesteps=total_timesteps,
#     317         callback=callback,
#     318         log_interval=log_interval,
#     319         tb_log_name=tb_log_name,
#     320         reset_num_timesteps=reset_num_timesteps,
#     321         progress_bar=progress_bar,
#     322     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\on_policy_algorithm.py:277, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     274 assert self.env is not None
#     276 while self.num_timesteps < total_timesteps:
# --> 277     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     279     if not continue_training:
#     280         break
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\on_policy_algorithm.py:177, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     173     self.policy.reset_noise(env.num_envs)
#     175 with th.no_grad():
#     176     # Convert to pytorch tensor or to TensorDict
# --> 177     obs_tensor = obs_as_tensor(self._last_obs, self.device)
#     178     actions, values, log_probs = self.policy(obs_tensor)
#     179 actions = actions.cpu().numpy()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\utils.py:483, in obs_as_tensor(obs, device)
#     475 """
#     476 Moves the observation to the given device.
#     477
#    (...)
#     480 :return: PyTorch tensor of the observation on a desired device.
#     481 """
#     482 if isinstance(obs, np.ndarray):
# --> 483     return th.as_tensor(obs, device=device)
#     484 elif isinstance(obs, dict):
#     485     return {key: th.as_tensor(_obs, device=device) for (key, _obs) in obs.items()}
#
# KeyboardInterrupt:
