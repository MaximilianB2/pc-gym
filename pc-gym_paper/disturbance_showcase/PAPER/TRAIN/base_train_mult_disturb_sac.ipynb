# %% [markdown]
# # Cloning the Repository (pc-gym)

# %%
# !dir pc-gym
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is F0B8-32A3
#
#  Directory of c:\Users\Usuario\Desktop\imperial_projects\VSCode\pcgym2\train\base
# File Not Found

# %%
# %cd pc-gym

# %% [markdown]
# # Importing Libraries

# %%
# %cd src

# %%
# %cd pcgym

# %%
# %cd C:/Users/Usuario/Desktop/imperial_projects/VSCode/pcgym2/pc-gym
# Out:
# C:\Users\Usuario\Desktop\imperial_projects\VSCode\pcgym2\pc-gym
# c:\Users\Usuario\Desktop\imperial_projects\VSCode\pcgym2\new_venv\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from dataclasses import dataclass
import numpy as np
import torch
import matplotlib.pyplot as plt
import gymnasium as gym
import torch.nn.functional as F
import copy
from stable_baselines3 import PPO,SAC,DDPG,TD3
import pcgym
from pcgym import make_env
import jax.numpy as jnp
#Global params
T = 26
nsteps = 101
# Global seed for reproducibility
seed = 1990
# Out:
# c:\Users\Usuario\Desktop\imperial_projects\VSCode\pcgym2\new_venv\Lib\site-packages\do_mpc\sysid\__init__.py:15: UserWarning: The ONNX feature is not available. Please install the full version of do-mpc to access this feature.
#   warnings.warn('The ONNX feature is not available. Please install the full version of do-mpc to access this feature.')
# c:\Users\Usuario\Desktop\imperial_projects\VSCode\pcgym2\new_venv\Lib\site-packages\do_mpc\opcua\__init__.py:14: UserWarning: The opcua feature is not available. Please install the full version of do-mpc to access this feature.
#   warnings.warn('The opcua feature is not available. Please install the full version of do-mpc to access this feature.')

# %% [markdown]
# # Saving and loading
#
# Saving and loading stable-baselines models is straightforward: you can directly call `.save()` and `.load()` on the models.

# %%
import os
# Create save dir
save_dir = "C:/Users/Usuario/Desktop/imperial_projects/VSCode/pcgym2/train/base/sac"
os.makedirs(save_dir, exist_ok=True)

# %% [markdown]
# # Monitoring experiments with W&B

# %%
# !wandb login
# api_key: 84af17cc9914cf1736f3a8e2733a2f361e4750bb

# !wandb login 84af17cc9914cf1736f3a8e2733a2f361e4750bb
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\Usuario\.netrc

# %% [markdown]
# # 1.1 Reactor Case Study

# %%
# @title Function to log the performance data
def log_performance(performance, test_label, file_path):
    with open(file_path, "a") as file:
        file.write(f"{test_label}: \n")
        file.write(f"scalarised_performance: {performance}\n\n")

file_path = f"{save_dir}/lcb_metric_safe.txt"

# %% [markdown]
# ### RL training

# %%
import numpy as np
import torch as th
from torch import nn  # Import torch.nn for activation functions

# Learning rate decay schedule
def cosine_annealing_schedule(progress_remaining: float, num_cycles=1, min_lr=0.005, max_lr=0.01):
    progress = 1.0 - progress_remaining
    lr = min_lr + (max_lr - min_lr) / 2 * (1 + np.cos(np.pi * num_cycles * progress))
    return lr

# Configuration for reinforcement learning model
config = {
    "policy": 'MlpPolicy',  # default: MlpPolicy
    "seed": 1990,
    "check_freq": 100,  # base: 12000 (~100 episodes)
    "n_eval_episodes": 10,  # evaluate the agent over 100 episodes in the evaluation environment
    "positive_definiteness_penalty_weight": 0,  # Set to 0 initially
    "derivative_penalty_weight": 0,  # Set to 0 initially
    'use_direct_penalty': False,  # choose between applying a penalty directly to the critic loss or adjusting the Q target values (derivative penalty)
    'allowed_increase_factor': 1,  # max increase value for both methods (derivative penalty)
    'total_timesteps': 500000
}

# The best hyperparameters found in previous runs
best_params = {
    'min_lr': 6.298973459520807e-05,
    'max_lr': 0.010222529480333347,
    'pi_layer_0_units': 2,
    'pi_layer_1_units': 3,
    'qf_layer_0_units': 4,
    'qf_layer_1_units': 6,
    'activation_fn': 'ReLU',
    'buffer_size': 500000,
    'batch_size': 256,
    'gamma': 0.9795136621593099,
    'tau': 0.019991455145873808,
    'learning_starts': 613,
    'train_freq': 16,
    'gradient_steps': -1,
    'ent_coef': 'auto',
    'total_timesteps': 200000
    # 'total_timesteps': 500000
}

# Update the config dictionary with the best parameters
config.update(best_params)

# Set the activation function directly based on best_params
if best_params['activation_fn'] == 'Tanh':
    activation_fn = th.nn.Tanh
elif best_params['activation_fn'] == 'ReLU':
    activation_fn = th.nn.ReLU
elif best_params['activation_fn'] == 'LeakyReLU':
    activation_fn = th.nn.LeakyReLU
else:
    raise ValueError("Unsupported activation function")

# # Create policy_kwargs with the fixed network architecture and activation function from best_params
policy_kwargs = dict(
    activation_fn=activation_fn,  # Use the activation function directly
    net_arch=dict(
        pi=[2 ** best_params['pi_layer_0_units'], 2 ** best_params['pi_layer_1_units']],
        qf=[2 ** best_params['qf_layer_0_units'], 2 ** best_params['qf_layer_1_units']]
    )
)

# %%
import torch as th
import numpy as np
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.common.policies import ActorCriticPolicy
from stable_baselines3.common.vec_env import DummyVecEnv

##################################################################################
# Environment and RL Definition
##################################################################################

# Enter required setpoints for each state. Enter None for states without setpoints.
SP = {
    'T': [324.475443431599 for _ in range(5)] + [340.0 for _ in range(nsteps - 5)],
}

# Continuous box action space
action_space = {
    'low': np.array([250]),
    'high': np.array([350])
}

# Continuous box observation space ([CA, T, CA_Setpoint, T_Setpoint])
observation_space = {
    'low': np.array([0.0, 200, 300]),
    'high': np.array([1, 600, 400])
}

r_scale = {
    'T': 1e-6  # Reward scale for each state,
}

# Define disturbance bounds
disturbance_bounds = {
    'low': np.array([310]),
    'high': np.array([390])
}

# Environment parameters
env_params_template = {
    'Nx': 2,
    'N': 100,
    'tsim': 26,
    'Nu': 1,
    'SP': SP,
    'o_space': observation_space,
    'a_space': action_space,
    'x0': np.array([0.87725294608097, 324.475443431599, 324.475443431599]),
    'model': 'cstr',
    'r_scale': r_scale,
    'normalise_a': True,
    'normalise_o': True,
    'noise': True,
    'integration_method': 'casadi',
    'noise_percentage': 0.001,  # 0.001,
    'disturbance_bounds': disturbance_bounds
}

# Add noise_percentage from env_params to config
config['noise_percentage'] = env_params_template['noise_percentage']

# Seed everything for reproducibility
def set_global_seeds(seed):
    np.random.seed(seed)
    th.manual_seed(seed)
    if th.cuda.is_available():
        th.cuda.manual_seed_all(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

# Function to create random disturbances
def create_random_disturbances(seed, nsteps, low=315, high=385):
    # Set the global seed for reproducibility
    set_global_seeds(seed)
    values = np.random.uniform(low, high, 3)  # Generate three random disturbance values within the specified range
    times = np.sort(np.random.choice(range(1, nsteps - 1), 2, replace=False))  # Select two unique time steps for disturbances
    times = np.append(times, nsteps)  # Append the total number of steps to get three periods
    times = np.diff([0] + times.tolist())  # Calculate the duration of each disturbance period
    disturbances = {'Ti': np.repeat(values, times)}  # Repeat the disturbance values according to the calculated durations
    return disturbances

# Create multiple environments with different disturbances
def create_parallel_envs(n_envs, seed):
    set_global_seeds(seed)
    envs = []
    disturbances_list = []
    for i in range(n_envs):
        env_params = env_params_template.copy()
        disturbances = create_random_disturbances(seed + i, nsteps)
        env_params.update({'disturbances': disturbances})
        disturbances_list.append(disturbances)
        envs.append(lambda: make_env(env_params))
    return DummyVecEnv(envs), disturbances_list

# Create evaluation environment using DummyVecEnv
def create_eval_env(seed, n_envs=1):
    set_global_seeds(seed)
    envs = []
    for i in range(n_envs):
        env_params = env_params_template.copy()
        disturbances = create_random_disturbances(seed + i, nsteps)
        env_params.update({'disturbances': disturbances})
        envs.append(lambda: make_env(env_params))
    return DummyVecEnv(envs)

eval_env = create_eval_env(seed=config['seed'], n_envs=1)

# %%
import wandb
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import SAC
from stable_baselines3.common.noise import OrnsteinUhlenbeckActionNoise
from stable_baselines3.common.callbacks import EvalCallback

# Initialize W&B
wandb.init(
    config=config,
    sync_tensorboard=True,  # Automatically upload SB3's tensorboard metrics
    project="pc-gym-paper-v3",
    name=f"train-base-SAC-mult-disturb-tot_{config['total_timesteps']}",
)

# Set the global seed for reproducibility
set_global_seeds(config['seed'])

# Number of parallel environments
n_envs = 10

# Create the parallel environments and get the disturbances
env, disturbances_list = create_parallel_envs(n_envs, config['seed'])

# Print the first disturbances
print("First disturbance used in training:", disturbances_list[0])

# Initialize the SAC model
model = SAC(
    config['policy'],
    env,
    learning_rate=lambda progress: cosine_annealing_schedule(progress, min_lr=config['min_lr'], max_lr=config['max_lr']),  # Cosine schedule
    buffer_size=config['buffer_size'],
    batch_size=config['batch_size'],
    gamma=config['gamma'],
    tau=config['tau'],
    ent_coef=config['ent_coef'],
    train_freq=config['train_freq'],
    gradient_steps=config['gradient_steps'],
    learning_starts=config['learning_starts'],
    policy_kwargs=policy_kwargs,  # Use custom policy network structure
    seed=seed,
    verbose=0,
    tensorboard_log="runs/sac",
    # Adding the optimized SAC-specific parameters to the model
    positive_definiteness_penalty_weight=config['positive_definiteness_penalty_weight'],
    derivative_penalty_weight=config['derivative_penalty_weight'],
    use_direct_penalty=config['use_direct_penalty'],
    allowed_increase_factor=config['allowed_increase_factor'],
)

# Create the evaluation environment
eval_env = create_eval_env(seed)

# Create evaluation callback
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=save_dir,
    log_path=save_dir,
    eval_freq=config['check_freq'],
    n_eval_episodes=config['n_eval_episodes'],
    deterministic=True,
    render=False
)

# Train the model with the callbacks
model.learn(total_timesteps=config['total_timesteps'], callback=eval_callback)

# Save the model
model.save(save_dir)

# Save the disturbances to a file for future reference
disturbances_file_path = os.path.join(save_dir, "disturbances_used_in_training.txt")
with open(disturbances_file_path, "w") as f:
    for i, disturbance in enumerate(disturbances_list):
        f.write(f"Disturbance {i+1}: {disturbance}\n")

# Finish the W&B run
wandb.finish()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: josetorraca (lades). Use `wandb login --relogin` to force relogin
# wandb version 0.18.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.6
# Run data is saved locally in <code>C:\Users\Usuario\Desktop\imperial_projects\VSCode\pcgym2\pc-gym\wandb\run-20240927_220256-zc83mz7w</code>
# Syncing run <strong><a href='https://wandb.ai/lades/pc-gym-paper-v3/runs/zc83mz7w' target="_blank">train-base-SAC-mult-disturb-tot_200000</a></strong> to <a href='https://wandb.ai/lades/pc-gym-paper-v3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/lades/pc-gym-paper-v3' target="_blank">https://wandb.ai/lades/pc-gym-paper-v3</a>
#  View run at <a href='https://wandb.ai/lades/pc-gym-paper-v3/runs/zc83mz7w' target="_blank">https://wandb.ai/lades/pc-gym-paper-v3/runs/zc83mz7w</a>
# First disturbance used in training: {'Ti': array([365.53840802, 365.53840802, 365.53840802, 365.53840802,
#        365.53840802, 365.53840802, 365.53840802, 365.53840802,
#        365.53840802, 365.53840802, 365.53840802, 365.53840802,
#        365.53840802, 365.53840802, 365.53840802, 365.53840802,
#        365.53840802, 320.42850404, 320.42850404, 320.42850404,
#        320.42850404, 320.42850404, 320.42850404, 320.42850404,
#        320.42850404, 320.42850404, 320.42850404, 320.42850404,
#        320.42850404, 320.42850404, 320.42850404, 320.42850404,
#        320.42850404, 320.42850404, 320.42850404, 320.42850404,
#        320.42850404, 320.42850404, 320.42850404, 320.42850404,
#        320.42850404, 320.42850404, 320.42850404, 320.42850404,
#        320.42850404, 320.42850404, 320.42850404, 320.42850404,
#        320.42850404, 320.42850404, 320.42850404, 320.42850404,
#        321.83357664, 321.83357664, 321.83357664, 321.83357664,
#        321.83357664, 321.83357664, 321.83357664, 321.83357664,
#        321.83357664, 321.83357664, 321.83357664, 321.83357664,
#        321.83357664, 321.83357664, 321.83357664, 321.83357664,
#        321.83357664, 321.83357664, 321.83357664, 321.83357664,
#        321.83357664, 321.83357664, 321.83357664, 321.83357664,
#        321.83357664, 321.83357664, 321.83357664, 321.83357664,
#        321.83357664, 321.83357664, 321.83357664, 321.83357664,
#        321.83357664, 321.83357664, 321.83357664, 321.83357664,
#        321.83357664, 321.83357664, 321.83357664, 321.83357664,
#        321.83357664, 321.83357664, 321.83357664, 321.83357664,
#        321.83357664, 321.83357664, 321.83357664, 321.83357664,
#        321.83357664])}
# c:\Users\Usuario\Desktop\imperial_projects\VSCode\pcgym2\new_venv\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=1000, episode_reward=-0.10 +/- 0.00
# Episode length: 99.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=2000, episode_reward=-0.34 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=3000, episode_reward=-0.10 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=4000, episode_reward=-0.33 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=5000, episode_reward=-0.27 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=6000, episode_reward=-0.04 +/- 0.00
# Episode length: 99.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=7000, episode_reward=-0.02 +/- 0.00
# Episode length: 99.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=8000, episode_reward=-0.04 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=9000, episode_reward=-0.03 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=10000, episode_reward=-0.02 +/- 0.00
# Episode length: 99.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=11000, episode_reward=-0.02 +/- 0.00
# Episode length: 99.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=12000, episode_reward=-0.06 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=13000, episode_reward=-0.06 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=14000, episode_reward=-0.05 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=15000, episode_reward=-0.04 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=16000, episode_reward=-0.03 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=17000, episode_reward=-0.07 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=18000, episode_reward=-0.05 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=19000, episode_reward=-0.08 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=20000, episode_reward=-0.06 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=21000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=22000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=23000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=24000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=25000, episode_reward=-0.02 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=26000, episode_reward=-0.02 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=27000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=28000, episode_reward=-0.01 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=29000, episode_reward=-0.01 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=30000, episode_reward=-0.01 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=31000, episode_reward=-0.01 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=32000, episode_reward=-0.02 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=33000, episode_reward=-0.01 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=34000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=35000, episode_reward=-0.01 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=36000, episode_reward=-0.01 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=37000, episode_reward=-0.01 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=38000, episode_reward=-0.01 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=39000, episode_reward=-0.01 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=40000, episode_reward=-0.01 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=41000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=42000, episode_reward=-0.01 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=43000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=44000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=45000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=46000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=47000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=48000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=49000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=51000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=52000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=53000, episode_reward=-0.01 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=54000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=55000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=56000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=57000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=58000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=59000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=60000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=61000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=62000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=63000, episode_reward=-0.01 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=64000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=65000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=66000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=67000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=68000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=69000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=70000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=71000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=72000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=73000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=74000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=75000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=76000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=77000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=78000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=79000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=80000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=81000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=82000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=83000, episode_reward=-0.01 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=84000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=85000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=86000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=87000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=88000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=89000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=90000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=91000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=92000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=93000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=94000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=95000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=96000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=97000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=98000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=99000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=100000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=101000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=102000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=103000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=104000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=105000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=106000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=107000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=108000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=109000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=110000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=111000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=112000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=113000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=114000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=115000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=116000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=117000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=118000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=119000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=120000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=121000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=122000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=123000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=124000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=125000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=126000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=127000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=128000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=129000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=130000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=131000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=132000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=133000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=134000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=135000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=136000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=137000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=138000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=139000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=140000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=141000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=142000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=143000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=144000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=145000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=146000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=147000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=148000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=149000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=150000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=151000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=152000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=153000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=154000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=155000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=156000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=157000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=158000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=159000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=160000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=161000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=162000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=163000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=164000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=165000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=166000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=167000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=168000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=169000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=170000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=171000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=172000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=173000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=174000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=175000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=176000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=177000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=178000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=179000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=180000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=181000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=182000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=183000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=184000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=185000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=186000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=187000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=188000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=189000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=190000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=191000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=192000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=193000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=194000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=195000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=196000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=197000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=198000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=199000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# Eval num_timesteps=200000, episode_reward=-0.00 +/- 0.00
# Episode length: 99.00 +/- 0.00
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/mean_ep_length</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/mean_reward</td><td>▁▇▇▇████████████████████████████████████</td></tr><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>time/fps</td><td>█▄▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂</td></tr><tr><td>train/actor_loss</td><td>▁█▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>train/critic_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/ent_coef</td><td>█▁▂▁▁▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/ent_coef_loss</td><td>█▅▇▇▅▇▄▇▆▄▅▅█▆█▆▅▄▆▁▇▄▇▆▇▃▆▃▆▄▅▇▄▆▆▆▆▇▆▇</td></tr><tr><td>train/learning_rate</td><td>███████▇▇▇▇▇▆▆▆▆▆▅▅▅▄▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/mean_ep_length</td><td>99.0</td></tr><tr><td>eval/mean_reward</td><td>-0.00074</td></tr><tr><td>global_step</td><td>200000</td></tr><tr><td>time/fps</td><td>117.0</td></tr><tr><td>train/actor_loss</td><td>0.00166</td></tr><tr><td>train/critic_loss</td><td>0.0</td></tr><tr><td>train/ent_coef</td><td>3e-05</td></tr><tr><td>train/ent_coef_loss</td><td>0.14041</td></tr><tr><td>train/learning_rate</td><td>6e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">train-base-SAC-mult-disturb-tot_200000</strong> at: <a href='https://wandb.ai/lades/pc-gym-paper-v3/runs/zc83mz7w' target="_blank">https://wandb.ai/lades/pc-gym-paper-v3/runs/zc83mz7w</a><br/> View project at: <a href='https://wandb.ai/lades/pc-gym-paper-v3' target="_blank">https://wandb.ai/lades/pc-gym-paper-v3</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>.\wandb\run-20240927_220256-zc83mz7w\logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
